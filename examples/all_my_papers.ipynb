# %%
from my_scientific_profile.papers.papers import fetch_all_paper_infos
from my_scientific_profile.database.papers import convert_papers_to_dataframe
from my_scientific_profile.database.papers import load_all_papers_from_s3
from my_scientific_profile.database.aws_s3 import S3_BUCKET, S3_CLIENT

# %%
loaded_papers = load_all_papers_from_s3(S3_CLIENT, S3_BUCKET)
len(loaded_papers)
# Out:
# 75

# %% [markdown]
# The following will fetch _all_ works of the ORCID provided in the `config.yaml` file. This can take a little while.

# %%
papers = fetch_all_paper_infos()
# Out:
# 2023-10-26 11:26:36,431 - my_scientific_profile.orcid.utils - INFO - fetching works None
# 2023-10-26 11:26:36,432 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/0000-0001-9945-1271/works

# %%
df = convert_papers_to_dataframe(papers)
display(df)
# Out:
#                            doi  \
# 0   10.1038/s41597-023-02501-8
# 1   10.1038/s41467-023-40663-6
# 2     10.1021/acs.jctc.3c00201
# 3           10.1039/D3BM00412K
# 4    10.1016/j.bpj.2022.12.004
# ..                         ...
# 70           10.1021/ct200888u
# 71   10.1016/j.bpj.2011.03.056
# 72           10.1021/ja105206w
# 73           10.1063/1.3152842
# 74   10.1016/j.jcp.2009.05.011
#
#                                                 title    publication_date  \
# 0   Shared metadata for data-centric materials sci... 2023-09-14 15:07:13
# 1   Data-mining unveils structure–property–activit... 2023-08-23 10:03:03
# 2   Condensed-Phase Molecular Representation to Li... 2023-07-03 12:50:55
# 3   Inverse design of viral infectivity-enhancing ... 2023-06-15 11:01:18
# 4                    Induced asymmetries in membranes 2022-12-06 17:25:35
# ..                                                ...                 ...
# 70  Coarse-Grained and Atomistic Simulations of th... 2012-04-23 15:26:13
# 71  Structural Basis of Folding Cooperativity in M... 2011-06-18 16:42:31
# 72  Interplay between Secondary and Tertiary Struc... 2010-09-07 20:34:41
# 73  Generic coarse-grained model for protein foldi... 2009-06-18 22:23:46
# 74  Optimized convergence for multiple histogram a... 2009-05-19 05:37:31
#
#                                               authors  citation_count  \
# 0   [{'given': 'Luca M.', 'family': 'Ghiringhelli'...               0
# 1   [{'given': 'Kübra', 'family': 'Kaygisiz', 'aff...               0
# 2   [{'given': 'Bernadette', 'family': 'Mohr', 'af...               0
# 3   [{'given': 'Kübra', 'family': 'Kaygisiz', 'aff...               0
# 4   [{'given': 'Martin', 'family': 'Girard', 'affi...               2
# ..                                                ...             ...
# 70  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              22
# 71  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              30
# 72  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              46
# 73  [{'given': 'Tristan', 'family': 'Bereau', 'aff...             170
# 74  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              29
#
#                                             bib_entry  \
# 0   @article{Ghiringhelli_2023,\n\tdoi = {10.1038/...
# 1   @article{Kaygisiz_2023,\n\tdoi = {10.1038/s414...
# 2   @article{Mohr_2023,\n\tdoi = {10.1021/acs.jctc...
# 3   @article{Kaygisiz_2023,\n\tdoi = {10.1039/d3bm...
# 4   @article{Girard_2023,\n\tdoi = {10.1016/j.bpj....
# ..                                                ...
# 70  @article{Bereau_2012,\n\tdoi = {10.1021/ct2008...
# 71  @article{Bereau_2011,\n\tdoi = {10.1016/j.bpj....
# 72  @article{Bereau_2010,\n\tdoi = {10.1021/ja1052...
# 73  @article{Bereau_2009,\n\tdoi = {10.1063/1.3152...
# 74  @article{Bereau_2009,\n\tdoi = {10.1016/j.jcp....
#
#                                              abstract  \
# 0
# 1   <jats:title>Abstract</jats:title><jats:p>Gene ...
# 2   Molecular design requires systematic and broad...
# 3   Amyloid-like nanofibers from self-assembling p...
# 4   Lipid asymmetry in plasma membrane of eukaryot...
# ..                                                ...
# 70  A combination of coarse-grained (CG) and atomi...
# 71  Two-state cooperativity is an important charac...
# 72  Protein folding cooperativity is defined by th...
# 73  A generic coarse-grained (CG) protein model is...
# 74  We propose a new algorithm for solving the wei...
#
#                                                  tldr  year  embedding  ...  \
# 0   This paper presents an operative definition of...  2023        NaN  ...
# 1   This data-mining study elucidates the multi-sc...  2023        NaN  ...
# 2                                                None  2023        NaN  ...
# 3   These de novo sequences are the shortest activ...  2023        NaN  ...
# 4   It is shown that saturation asymmetry naturall...  2022        NaN  ...
# ..                                                ...   ...        ...  ...
# 70  This work combines CG and atomistic simulation...  2012        NaN  ...
# 71  It is shown that whereas short α-helices exhib...  2011        NaN  ...
# 72  It is found that the interplay between seconda...  2010        NaN  ...
# 73  The accuracy involved in folding not only the ...  2009        NaN  ...
# 74  A new algorithm for solving the weighted histo...  2009        NaN  ...
#
#    journal.pages journal.volume open_access.is_open_access  \
# 0           None           10.0                       True
# 1           None           14.0                       True
# 2           None            NaN                       True
# 3           None            NaN                       True
# 4      2092-2098          122.0                      False
# ..           ...            ...                        ...
# 70     3750-3758            8.0                      False
# 71     2764-2772          100.0                       True
# 72   13129-13131          132.0                       True
# 73        235106          130.0                       True
# 74     6119-6129          228.0                      False
#
#    open_access.open_access_status                open_access.landing_page_url  \
# 0                            gold  https://doi.org/10.1038/s41597-023-02501-8
# 1                            gold  https://doi.org/10.1038/s41467-023-40663-6
# 2                          hybrid    https://doi.org/10.1021/acs.jctc.3c00201
# 3                          hybrid          https://doi.org/10.1039/d3bm00412k
# 4                            None                                        None
# ..                            ...                                         ...
# 70                           None                                        None
# 71                         bronze   https://doi.org/10.1016/j.bpj.2011.03.056
# 72                         hybrid           https://doi.org/10.1021/ja105206w
# 73                          green   https://europepmc.org/articles/pmc3910140
# 74                           None                                        None
#
#                                   open_access.pdf_url  embedding.x  \
# 0   https://www.nature.com/articles/s41597-023-025...          NaN
# 1   https://www.nature.com/articles/s41467-023-406...          NaN
# 2                                                None     6.982270
# 3   https://pubs.rsc.org/en/content/articlepdf/202...     5.854815
# 4                                                None     4.781759
# ..                                                ...          ...
# 70                                               None     4.574881
# 71  http://www.cell.com/article/S0006349511004140/pdf     4.887036
# 72     https://pubs.acs.org/doi/pdf/10.1021/ja105206w     5.027872
# 73  https://europepmc.org/articles/pmc3910140?pdf=...     4.752363
# 74                                               None     6.024127
#
#    embedding.y embedding.topic_number                   embedding.topic_name
# 0          NaN                    NaN                                    NaN
# 1          NaN                    NaN                                    NaN
# 2    -2.369426                    0.0  cardiolipin | membrane | permeability
# 3    -1.253788                    3.0         sequence | dispersion | growth
# 4    -2.787106                    5.0           membrane | lipid | asymmetry
# ..         ...                    ...                                    ...
# 70   -0.426310                    6.0   twostate | cooperativity | structure
# 71   -0.581017                    6.0   twostate | cooperativity | structure
# 72   -0.432803                    6.0   twostate | cooperativity | structure
# 73   -0.725722                    6.0   twostate | cooperativity | structure
# 74   -0.561150                    2.0               kinetic | model | markov
#
# [75 rows x 24 columns]

# %% [markdown]
# From a Pandas dataframe we can easily store the data as a json or a csv, for instance. This can be done using `df.to_json()` or `df.to_csv()`, respectively.
#
# Otherwise, it's possible to store it online on an AWS S3 database. Given that you provide the access ID and secret as environment variables, you can push to the database

# %%
from my_scientific_profile.database.papers import save_all_papers_to_s3
from my_scientific_profile.database.aws_s3 import S3_BUCKET, S3_CLIENT

save_all_papers_to_s3(S3_CLIENT, S3_BUCKET)
