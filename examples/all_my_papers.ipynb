# %%
from my_scientific_profile.papers.papers import fetch_all_paper_infos
from my_scientific_profile.database.papers import convert_papers_to_dataframe
from my_scientific_profile.database.papers import load_all_papers_from_s3
from my_scientific_profile.database.aws_s3 import S3_BUCKET, S3_CLIENT

# %%
loaded_papers = load_all_papers_from_s3(S3_CLIENT, S3_BUCKET)
len(loaded_papers)
# Out:
# 73

# %% [markdown]
# The following will fetch _all_ works of the ORCID provided in the `config.yaml` file. This can take a little while.

# %%
papers = fetch_all_paper_infos()
# Out:
# 2023-10-04 11:32:51,889 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:Markus+AND+family-name:Kühbach
# 2023-10-04 11:32:51,890 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Markus+AND+family-name:Kühbach
# 2023-10-04 11:32:52,168 - my_scientific_profile.orcid.authors - INFO - Entries received: 1
# 2023-10-04 11:32:52,170 - my_scientific_profile.orcid.utils - INFO - fetching employments None
# 2023-10-04 11:32:52,171 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/0000-0002-7117-5196/employments
# 2023-10-04 11:32:52,456 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:Alvin\ Noe+AND+family-name:Ladines
# 2023-10-04 11:32:52,458 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Alvin\ Noe+AND+family-name:Ladines
# 2023-10-04 11:32:52,849 - my_scientific_profile.orcid.authors - INFO - Entries received: 1
# 2023-10-04 11:32:52,851 - my_scientific_profile.orcid.utils - INFO - fetching employments None
# 2023-10-04 11:32:52,851 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/0000-0003-0077-2097/employments
# 2023-10-04 11:32:53,139 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:Patrick+AND+family-name:Lambrix
# 2023-10-04 11:32:53,141 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Patrick+AND+family-name:Lambrix
# 2023-10-04 11:32:53,403 - my_scientific_profile.orcid.authors - INFO - Entries received: 1
# 2023-10-04 11:32:53,404 - my_scientific_profile.orcid.utils - INFO - fetching employments None
# 2023-10-04 11:32:53,405 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/0000-0002-9084-0470/employments
# 2023-10-04 11:32:53,961 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:Maja\-Olivia+AND+family-name:Himmer
# 2023-10-04 11:32:53,963 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Maja\-Olivia+AND+family-name:Himmer
# 2023-10-04 11:32:54,264 - my_scientific_profile.orcid.authors - INFO - Entries received: 0
# 2023-10-04 11:32:54,265 - my_scientific_profile.authors.authors - INFO - ORCID search results returned 0 results
# []
# 2023-10-04 11:32:54,265 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:Sergey\ V\.+AND+family-name:Levchenko
# 2023-10-04 11:32:54,266 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Sergey\ V\.+AND+family-name:Levchenko
# 2023-10-04 11:32:54,884 - my_scientific_profile.orcid.authors - INFO - Entries received: 4
# 2023-10-04 11:32:54,886 - my_scientific_profile.authors.authors - INFO - ORCID search results returned 4 results
# [OrcidAuthor(given_names='Sergey', family_names='Levchenko', orcid_id='0000-0002-6332-7882', credit_name=None, other_name=[], email=[]), OrcidAuthor(given_names='Sergey', family_names='Levchenko', orcid_id='0009-0001-5366-2900', credit_name=None, other_name=[], email=[]), OrcidAuthor(given_names='Sergey', family_names='Levchenko', orcid_id='0000-0001-5813-8473', credit_name=None, other_name=[], email=[])] ...
# 2023-10-04 11:32:54,887 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:Micael+AND+family-name:Oliveira
# 2023-10-04 11:32:54,888 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Micael+AND+family-name:Oliveira
# 2023-10-04 11:32:55,180 - my_scientific_profile.orcid.authors - INFO - Entries received: 13
# 2023-10-04 11:32:55,182 - my_scientific_profile.authors.authors - INFO - ORCID search results returned 13 results
# [OrcidAuthor(given_names='Micael', family_names='Oliveira', orcid_id='0000-0003-1364-0907', credit_name='Micael J. T. Oliveira', other_name=[], email=[]), OrcidAuthor(given_names='Micael', family_names='Oliveira', orcid_id='0000-0003-4156-5246', credit_name=None, other_name=[], email=[]), OrcidAuthor(given_names='Micael', family_names='Oliveira Marques', orcid_id='0000-0002-1634-0566', credit_name=None, other_name=[], email=[])] ...
# 2023-10-04 11:32:55,183 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:Adam+AND+family-name:Michalchuk
# 2023-10-04 11:32:55,184 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Adam+AND+family-name:Michalchuk
# 2023-10-04 11:32:55,465 - my_scientific_profile.orcid.authors - INFO - Entries received: 1
# 2023-10-04 11:32:55,466 - my_scientific_profile.orcid.utils - INFO - fetching employments None
# 2023-10-04 11:32:55,467 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/0000-0001-7405-3269/employments
# 2023-10-04 11:32:55,974 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:Ronald\ E\.+AND+family-name:Miller
# 2023-10-04 11:32:55,975 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Ronald\ E\.+AND+family-name:Miller
# 2023-10-04 11:32:56,269 - my_scientific_profile.orcid.authors - INFO - Entries received: 31
# 2023-10-04 11:32:56,272 - my_scientific_profile.authors.authors - INFO - ORCID search results returned 31 results
# [OrcidAuthor(given_names='Ronald', family_names='Miller', orcid_id='0000-0002-5878-0893', credit_name=None, other_name=[], email=[]), OrcidAuthor(given_names='Ronald', family_names='Miller', orcid_id='0000-0003-2483-5099', credit_name=None, other_name=[], email=[]), OrcidAuthor(given_names='Ronald', family_names='Miller', orcid_id='0000-0002-6410-9326', credit_name=None, other_name=[], email=[])] ...
# 2023-10-04 11:32:56,273 - my_scientific_profile.orcid.utils - INFO - fetching expanded-search ?q=given-names:
- my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/expanded-search/?q=given-names:Matthias+AND+family-name:Scheffler
# 2023-10-04 11:33:05,773 - my_scientific_profile.orcid.authors - INFO - Entries received: 3
# 2023-10-04 11:33:05,775 - my_scientific_profile.authors.authors - INFO - ORCID search results returned 3 results
# [OrcidAuthor(given_names='Matthias', family_names='Scheffler', orcid_id='0000-0002-1280-9873', credit_name=None, other_name=[], email=[]), OrcidAuthor(given_names='Matthias', family_names='Scheffler', orcid_id='0000-0002-1733-0263', credit_name=None, other_name=[], email=[]), OrcidAuthor(given_names='Matthias', family_names='Scheffler', orcid_id='0000-0002-9031-1368', credit_name=None, other_name=[], email=[])]

# %%
df = convert_papers_to_dataframe(papers)
display(df)
# Out:
#                                doi  \
# 0       10.1038/s41597-023-02501-8
# 1         10.1021/acs.jctc.3c00201
# 2               10.1039/D3BM00412K
# 3   10.1021/acsfoodscitech.2c00251
# 4                10.1063/5.0104914
# ..                             ...
# 69               10.1021/ct200888u
# 70       10.1016/j.bpj.2011.03.056
# 71               10.1021/ja105206w
# 72               10.1063/1.3152842
# 73       10.1016/j.jcp.2009.05.011
#
#                                                 title  \
# 0   Shared metadata for data-centric materials sci...
# 1   Condensed-Phase Molecular Representation to Li...
# 2   Inverse design of viral infectivity-enhancing ...
# 3   Identifying Sequential Residue Patterns in Bit...
# 4   Broad chemical transferability in structure-ba...
# ..                                                ...
# 69  Coarse-Grained and Atomistic Simulations of th...
# 70  Structural Basis of Folding Cooperativity in M...
# 71  Interplay between Secondary and Tertiary Struc...
# 72  Generic coarse-grained model for protein foldi...
# 73  Optimized convergence for multiple histogram a...
#
#              publication_date  \
# 0   2023-09-14 15:07:13+00:00
# 1         2023-07-03 12:50:55
# 2         2023-06-15 11:01:18
# 3         2022-11-09 14:00:22
# 4         2022-08-12 11:51:35
# ..                        ...
# 69        2012-04-23 15:26:13
# 70        2011-06-18 16:42:31
# 71        2010-09-07 20:34:41
# 72        2009-06-18 22:23:46
# 73        2009-05-19 05:37:31
#
#                                               authors  citation_count  \
# 0   [{'given': 'Luca M.', 'family': 'Ghiringhelli'...               0
# 1   [{'given': 'Bernadette', 'family': 'Mohr', 'af...               0
# 2   [{'given': 'Kübra', 'family': 'Kaygisiz', 'aff...               0
# 3   [{'given': 'Arghya', 'family': 'Dutta', 'affil...               1
# 4   [{'given': 'Kiran', 'family': 'Kanekal', 'affi...               2
# ..                                                ...             ...
# 69  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              22
# 70  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              30
# 71  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              46
# 72  [{'given': 'Tristan', 'family': 'Bereau', 'aff...             170
# 73  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              29
#
#                                             bib_entry  \
# 0   @article{Ghiringhelli_2023,\n\tdoi = {10.1038/...
# 1   @article{Mohr_2023,\n\tdoi = {10.1021/acs.jctc...
# 2   @article{Kaygisiz_2023,\n\tdoi = {10.1039/d3bm...
# 3   @article{Dutta_2022,\n\tdoi = {10.1021/acsfood...
# 4   @article{Kanekal_2022,\n\tdoi = {10.1063/5.010...
# ..                                                ...
# 69  @article{Bereau_2012,\n\tdoi = {10.1021/ct2008...
# 70  @article{Bereau_2011,\n\tdoi = {10.1016/j.bpj....
# 71  @article{Bereau_2010,\n\tdoi = {10.1021/ja1052...
# 72  @article{Bereau_2009,\n\tdoi = {10.1063/1.3152...
# 73  @article{Bereau_2009,\n\tdoi = {10.1016/j.jcp....
#
#                                              abstract  \
# 0
# 1   Molecular design requires systematic and broad...
# 2   Amyloid-like nanofibers from self-assembling p...
# 3   The primary structures of peptides, originatin...
# 4   Compared to top-down coarse-grained (CG) model...
# ..                                                ...
# 69  A combination of coarse-grained (CG) and atomi...
# 70  Two-state cooperativity is an important charac...
# 71  Protein folding cooperativity is defined by th...
# 72  A generic coarse-grained (CG) protein model is...
# 73  We propose a new algorithm for solving the wei...
#
#                                                  tldr  year  embedding  ...  \
# 0   This paper presents an operative definition of...  2023        NaN  ...
# 1                                                None  2023        NaN  ...
# 2   These de novo sequences are the shortest activ...  2023        NaN  ...
# 3   This work proposes a method that coarse-grains...  2022        NaN  ...
# 4                                                None  2022        NaN  ...
# ..                                                ...   ...        ...  ...
# 69  This work combines CG and atomistic simulation...  2012        NaN  ...
# 70  It is shown that whereas short α-helices exhib...  2011        NaN  ...
# 71  It is found that the interplay between seconda...  2010        NaN  ...
# 72  The accuracy involved in folding not only the ...  2009        NaN  ...
# 73  A new algorithm for solving the weighted histo...  2009        NaN  ...
#
#    journal.pages journal.volume open_access.is_open_access  \
# 0           None           10.0                       True
# 1           None            NaN                       True
# 2           None            NaN                       True
# 3      1773-1780            2.0                       True
# 4         104102          157.0                       True
# ..           ...            ...                        ...
# 69     3750-3758            8.0                      False
# 70     2764-2772          100.0                       True
# 71   13129-13131          132.0                       True
# 72        235106          130.0                       True
# 73     6119-6129          228.0                      False
#
#    open_access.open_access_status  \
# 0                            gold
# 1                          hybrid
# 2                          hybrid
# 3                          hybrid
# 4                          hybrid
# ..                            ...
# 69                           None
# 70                         bronze
# 71                         hybrid
# 72                          green
# 73                           None
#
#                       open_access.landing_page_url  \
# 0       https://doi.org/10.1038/s41597-023-02501-8
# 1         https://doi.org/10.1021/acs.jctc.3c00201
# 2               https://doi.org/10.1039/d3bm00412k
# 3   https://doi.org/10.1021/acsfoodscitech.2c00251
# 4                https://doi.org/10.1063/5.0104914
# ..                                             ...
# 69                                            None
# 70       https://doi.org/10.1016/j.bpj.2011.03.056
# 71               https://doi.org/10.1021/ja105206w
# 72       https://europepmc.org/articles/pmc3910140
# 73                                            None
#
#                                   open_access.pdf_url  embedding.x  \
# 0   https://www.nature.com/articles/s41597-023-025...          NaN
# 1                                                None     6.982270
# 2   https://pubs.rsc.org/en/content/articlepdf/202...     5.854815
# 3   https://pubs.acs.org/doi/pdf/10.1021/acsfoodsc...     4.934255
# 4   https://aip.scitation.org/doi/pdf/10.1063/5.01...     7.762390
# ..                                                ...          ...
# 69                                               None     4.574881
# 70  http://www.cell.com/article/S0006349511004140/pdf     4.887036
# 71     https://pubs.acs.org/doi/pdf/10.1021/ja105206w     5.027872
# 72  https://europepmc.org/articles/pmc3910140?pdf=...     4.752363
# 73                                               None     6.024127
#
#    embedding.y embedding.topic_number                   embedding.topic_name
# 0          NaN                    NaN                                    NaN
# 1    -2.369426                    0.0  cardiolipin | membrane | permeability
# 2    -1.253788                    3.0         sequence | dispersion | growth
# 3    -1.088588                    1.0          peptide | folding | insertion
# 4    -1.373528                    8.0               model | cg | correlation
# ..         ...                    ...                                    ...
# 69   -0.426310                    6.0   twostate | cooperativity | structure
# 70   -0.581017                    6.0   twostate | cooperativity | structure
# 71   -0.432803                    6.0   twostate | cooperativity | structure
# 72   -0.725722                    6.0   twostate | cooperativity | structure
# 73   -0.561150                    2.0               kinetic | model | markov
#
# [74 rows x 24 columns]

# %% [markdown]
# From a Pandas dataframe we can easily store the data as a json or a csv, for instance. This can be done using `df.to_json()` or `df.to_csv()`, respectively.
#
# Otherwise, it's possible to store it online on an AWS S3 database. Given that you provide the access ID and secret as environment variables, you can push to the database

# %%
from my_scientific_profile.database.papers import save_all_papers_to_s3
from my_scientific_profile.database.aws_s3 import S3_BUCKET, S3_CLIENT

save_all_papers_to_s3(S3_CLIENT, S3_BUCKET)
