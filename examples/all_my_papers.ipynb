# %%
from dotenv import load_dotenv
load_dotenv('../.env')
# Out:
# True

# %%
from my_scientific_profile.papers.papers import fetch_all_paper_infos, fetch_paper_info
from my_scientific_profile.database.papers import convert_papers_to_dataframe
from my_scientific_profile.database.papers import load_all_papers_from_s3
from my_scientific_profile.database.aws_s3 import S3_BUCKET, S3_CLIENT

# %%
loaded_papers = load_all_papers_from_s3(S3_CLIENT, S3_BUCKET)
len(loaded_papers)
# Out:
# 80

# %% [markdown]
# The following will fetch _all_ works of the ORCID provided in the `config.yaml` file. This can take a little while.

# %%
papers = fetch_all_paper_infos()
# Out:
# 2025-09-29 16:01:14,564 - my_scientific_profile.orcid.utils - INFO - fetching works None with ORCID 0000-0001-9945-1271
# 2025-09-29 16:01:14,566 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/0000-0001-9945-1271/works
# 2025-09-29 16:01:15,512 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.1101/2025.07.13.664596
# 2025-09-29 16:01:16,179 - my_scientific_profile.semantic_scholar.utils - INFO - fetching Semantic Scholar paper info 10.1101/2025.07.13.664596
# 2025-09-29 16:01:16,609 - my_scientific_profile.orcid.utils - INFO - fetching work 188195695 with ORCID None
# 2025-09-29 16:01:16,610 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/188195695
# 2025-09-29 16:01:17,054 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.1101/2025.07.13.664596
# 2025-09-29 16:01:17,058 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.5281/zenodo.15783891
# 2025-09-29 16:01:17,700 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.5281/zenodo.15783891
# 2025-09-29 16:01:17,704 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.5281/zenodo.14895189
# 2025-09-29 16:01:18,373 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.5281/zenodo.14895189
# 2025-09-29 16:01:18,375 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.5281/zenodo.15446343
# 2025-09-29 16:01:19,021 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.5281/zenodo.15446343
# 2025-09-29 16:01:19,024 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.1063/5.0251736
# 2025-09-29 16:01:19,700 - my_scientific_profile.semantic_scholar.utils - INFO - fetching Semantic Scholar paper info 10.1063/5.0251736
# 2025-09-29 16:01:20,386 - my_scientific_profile.orcid.utils - INFO - fetching work 180854216 with ORCID None
# 2025-09-29 16:01:20,386 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/180854216
# 2025-09-29 16:01:20,754 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.1063/5.0251736
# 2025-09-29 16:01:20,757 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.1039/D5SC03855C
# 2025-09-29 16:01:21,474 - my_scientific_profile.semantic_scholar.utils - INFO - fetching Semantic Scholar paper info 10.1039/D5SC03855C
# 2025-09-29 16:01:22,195 - my_scientific_profile.orcid.utils - INFO - fetching work 189447839 with ORCID None
# 2025-09-29 16:01:22,196 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/189447839
# 2025-09-29 16:01:22,574 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.1039/D5SC03855C
# 2025-09-29 16:01:22,577 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.26434/chemrxiv-2024-m9sk0-v4
# 2025-09-29 16:01:23,243 - my_scientific_profile.semantic_scholar.utils - INFO - fetching Semantic Scholar paper info 10.26434/chemrxiv-2024-m9sk0-v4
# 2025-09-29 16:01:23,697 - my_scientific_profile.orcid.utils - INFO - fetching work 154395706 with ORCID None
# 2025-09-29 16:01:23,698 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/154395706
# 2025-09-29 16:01:24,125 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.26434/chemrxiv-2024-m9sk0-v4
# 2025-09-29 16:01:24,128 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.26434/chemrxiv-2024-m9sk0-v2
# 2025-09-29 16:01:24,788 - my_scientific_profile.semantic_scholar.utils - INFO - fetching Semantic Scholar paper info 10.26434/chemrxiv-2024-m9sk0-v2
# 2025-09-29 16:01:25,562 - my_scientific_profile.orcid.utils - INFO - fetching work 154375508 with ORCID None
# 2025-09-29 16:01:25,563 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/154375508
# 2025-09-29 16:01:26,001 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.26434/chemrxiv-2024-m9sk0-v2
# 2025-09-29 16:01:26,003 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.26434/chemrxiv-2024-m9sk0-v3
# 2025-09-29 16:01:26,689 - my_scientific_profile.semantic_scholar.utils - INFO - fetching Semantic Scholar paper info 10.26434/chemrxiv-2024-m9sk0-v3
# 2025-09-29 16:01:27,424 - my_scientific_profile.orcid.utils - INFO - fetching work 154375509 with ORCID None
# 2025-09-29 16:01:27,425 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/154375509
# 2025-09-29 16:01:27,911 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.26434/chemrxiv-2024-m9sk0-v3

# %%
df = convert_papers_to_dataframe(papers)
display(df)
# Out:
#                             doi  \
# 0      10.1021/acs.jcim.4c01754
# 1   10.1021/acs.jpclett.4c01958
# 2            10.1039/D4CE00752B
# 3      10.1021/acs.jcim.4c01300
# 4      10.1088/1361-651X/ad4d0d
# ..                          ...
# 75            10.1021/ct200888u
# 76    10.1016/j.bpj.2011.03.056
# 77            10.1021/ja105206w
# 78            10.1063/1.3152842
# 79    10.1016/j.jcp.2009.05.011
#
#                                                 title    publication_date  \
# 0   Martignac: Computational Workflows for Reprodu... 2024-12-02 16:11:08
# 1   Neural Thermodynamic Integration: Free Energie... 2024-11-06 15:50:48
# 2   Robust and efficient reranking in crystal stru... 2024-10-04 12:21:07
# 3   EDITORIAL: Chemical Compound Space Exploration... 2024-08-12 07:29:51
# 4           Roadmap on data-centric materials science 2024-05-17 22:25:08
# ..                                                ...                 ...
# 75  Coarse-Grained and Atomistic Simulations of th... 2012-04-23 15:26:13
# 76  Structural Basis of Folding Cooperativity in M... 2011-06-18 16:42:31
# 77  Interplay between Secondary and Tertiary Struc... 2010-09-07 20:34:41
# 78  Generic coarse-grained model for protein foldi... 2009-06-18 22:23:46
# 79  Optimized convergence for multiple histogram a... 2009-05-19 05:37:31
#
#                                               authors  citation_count  \
# 0   [{'given': 'Tristan', 'family': 'Bereau', 'aff...               1
# 1   [{'given': 'Bálint', 'family': 'Máté', 'affili...               0
# 2   [{'given': 'Andrea', 'family': 'Anelli', 'affi...               0
# 3   [{'given': 'Ganna', 'family': 'Gryn’Ova', 'aff...               0
# 4   [{'given': 'Stefan', 'family': 'Bauer', 'affil...               5
# ..                                                ...             ...
# 75  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              22
# 76  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              30
# 77  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              47
# 78  [{'given': 'Tristan', 'family': 'Bereau', 'aff...             183
# 79  [{'given': 'Tristan', 'family': 'Bereau', 'aff...              29
#
#                                             bib_entry  \
# 0    @article{Bereau_2024, title={Martignac: Compu...
# 1    @article{M_t__2024, title={Neural Thermodynam...
# 2    @article{Anelli_2024, title={Robust and effic...
# 3    @article{Gryn_ova_2024, title={EDITORIAL: Che...
# 4    @article{Bauer_2024, title={Roadmap on data-c...
# ..                                                ...
# 75   @article{Bereau_2012, title={Coarse-Grained a...
# 76   @article{Bereau_2011, title={Structural Basis...
# 77   @article{Bereau_2010, title={Interplay betwee...
# 78   @article{Bereau_2009, title={Generic coarse-g...
# 79   @article{Bereau_2009, title={Optimized conver...
#
#                                              abstract  \
# 0   Despite their wide use and far-reaching implic...
# 1   Thermodynamic integration (TI) offers a rigoro...
# 2   We accelerate a key step in crystal structure ...
# 3
# 4   Science is and always has been based on data, ...
# ..                                                ...
# 75  A combination of coarse-grained (CG) and atomi...
# 76  Two-state cooperativity is an important charac...
# 77  Protein folding cooperativity is defined by th...
# 78  A generic coarse-grained (CG) protein model is...
# 79  We propose a new algorithm for solving the wei...
#
#                                                  tldr  year embedding  \
# 0   This work introduces Martignac: computational ...  2024      None
# 1   This work parametrize a time-dependent Hamilto...  2024      None
# 2                                                None  2024      None
# 3                                                None  2024      None
# 4   This Roadmap on Data-Centric Materials Science...  2024      None
# ..                                                ...   ...       ...
# 75  This work combines CG and atomistic simulation...  2012      None
# 76  It is shown that whereas short α-helices exhib...  2011      None
# 77  It is found that it is the interplay between s...  2010      None
# 78  The accuracy involved in folding not only the ...  2009      None
# 79  A new algorithm for solving the weighted histo...  2009      None
#
#                                          journal.name  \
# 0        Journal of Chemical Information and Modeling
# 1           The Journal of Physical Chemistry Letters
# 2                                        CrystEngComm
# 3        Journal of Chemical Information and Modeling
# 4   Modelling and Simulation in Materials Science ...
# ..                                                ...
# 75         Journal of Chemical Theory and Computation
# 76                                Biophysical Journal
# 77           Journal of the American Chemical Society
# 78                    The Journal of Chemical Physics
# 79                   Journal of Computational Physics
#
#                                     journal.url journal.issue  \
# 0      https://doi.org/10.1021/acs.jcim.4c01754            24
# 1   https://doi.org/10.1021/acs.jpclett.4c01958            45
# 2            https://doi.org/10.1039/d4ce00752b            41
# 3      https://doi.org/10.1021/acs.jcim.4c01300            15
# 4      https://doi.org/10.1088/1361-651x/ad4d0d             6
# ..                                          ...           ...
# 75            https://doi.org/10.1021/ct200888u            10
# 76    https://doi.org/10.1016/j.bpj.2011.03.056            11
# 77            https://doi.org/10.1021/ja105206w            38
# 78            https://doi.org/10.1063/1.3152842            23
# 79    https://doi.org/10.1016/j.jcp.2009.05.011            17
#
#                  journal.abbreviation journal.pages  journal.volume  \
# 0                J. Chem. Inf. Model.     9413-9423              64
# 1                J. Phys. Chem. Lett.   11395-11404              15
# 2                        CrystEngComm     5845-5849              26
# 3                J. Chem. Inf. Model.     5737-5738              64
# 4   Modelling Simul. Mater. Sci. Eng.        063301              32
# ..                                ...           ...             ...
# 75            J. Chem. Theory Comput.     3750-3758               8
# 76                Biophysical Journal     2764-2772             100
# 77                  J. Am. Chem. Soc.   13129-13131             132
# 78    The Journal of Chemical Physics          None             130
# 79   Journal of Computational Physics     6119-6129             228
#
#     open_access.is_open_access open_access.open_access_status  \
# 0                         True                          green
# 1                         True                          green
# 2                         True                         hybrid
# 3                         True                         hybrid
# 4                         True                         hybrid
# ..                         ...                            ...
# 75                       False                           None
# 76                        True                          green
# 77                        True                         bronze
# 78                        True                          green
# 79                       False                           None
#
#                  open_access.landing_page_url  \
# 0             http://arxiv.org/abs/2409.15478
# 1            https://arxiv.org/abs/2406.02313
# 2          https://doi.org/10.1039/d4ce00752b
# 3    https://doi.org/10.1021/acs.jcim.4c01300
# 4    https://doi.org/10.1088/1361-651x/ad4d0d
# ..                                        ...
# 75                                       None
# 76  https://europepmc.org/articles/pmc3117192
# 77          https://doi.org/10.1021/ja105206w
# 78  https://europepmc.org/articles/pmc3910140
# 79                                       None
#
#                                   open_access.pdf_url
# 0                     http://arxiv.org/pdf/2409.15478
# 1                    https://arxiv.org/pdf/2406.02313
# 2                                                None
# 3   https://pubs.acs.org/doi/pdf/10.1021/acs.jcim....
# 4   https://iopscience.iop.org/article/10.1088/136...
# ..                                                ...
# 75                                               None
# 76  https://europepmc.org/articles/pmc3117192?pdf=...
# 77     https://pubs.acs.org/doi/pdf/10.1021/ja105206w
# 78  https://europepmc.org/articles/pmc3910140?pdf=...
# 79                                               None
#
# [80 rows x 20 columns]

# %% [markdown]
# From a Pandas dataframe we can easily store the data as a json or a csv, for instance. This can be done using `df.to_json()` or `df.to_csv()`, respectively.
#
# Otherwise, it's possible to store it online on an AWS S3 database. Given that you provide the access ID and secret as environment variables, you can push to the database

# %%
from my_scientific_profile.database.papers import save_all_papers_to_s3
from my_scientific_profile.database.aws_s3 import S3_BUCKET, S3_CLIENT

save_all_papers_to_s3(S3_CLIENT, S3_BUCKET)
# Out:
# 2025-09-29 16:02:01,703 - my_scientific_profile.orcid.utils - INFO - fetching work 188195695 with ORCID None
# 2025-09-29 16:02:01,704 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/188195695
# 2025-09-29 16:02:02,114 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.1101/2025.07.13.664596
# 2025-09-29 16:02:02,118 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.5281/zenodo.15783891
# 2025-09-29 16:02:02,795 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.5281/zenodo.15783891
# 2025-09-29 16:02:02,799 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.5281/zenodo.14895189
# 2025-09-29 16:02:03,457 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.5281/zenodo.14895189
# 2025-09-29 16:02:03,461 - my_scientific_profile.crossref.works - INFO - fetching Crossref info for doi 10.5281/zenodo.15446343
# 2025-09-29 16:02:04,136 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.5281/zenodo.15446343
# 2025-09-29 16:02:04,141 - my_scientific_profile.orcid.utils - INFO - fetching work 180854216 with ORCID None
# 2025-09-29 16:02:04,142 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/180854216
# 2025-09-29 16:02:04,532 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.1063/5.0251736
# 2025-09-29 16:02:04,537 - my_scientific_profile.orcid.utils - INFO - fetching work 189447839 with ORCID None
# 2025-09-29 16:02:04,538 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/189447839
# 2025-09-29 16:02:04,955 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.1039/D5SC03855C
# 2025-09-29 16:02:04,959 - my_scientific_profile.orcid.utils - INFO - fetching work 154395706 with ORCID None
# 2025-09-29 16:02:04,961 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/154395706
# 2025-09-29 16:02:05,385 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.26434/chemrxiv-2024-m9sk0-v4
# 2025-09-29 16:02:05,388 - my_scientific_profile.orcid.utils - INFO - fetching work 154375508 with ORCID None
# 2025-09-29 16:02:05,388 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/154375508
# 2025-09-29 16:02:05,808 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.26434/chemrxiv-2024-m9sk0-v2
# 2025-09-29 16:02:05,813 - my_scientific_profile.orcid.utils - INFO - fetching work 154375509 with ORCID None
# 2025-09-29 16:02:05,814 - my_scientific_profile.orcid.utils - INFO - url https://pub.orcid.org/v3.0/work/154375509
# 2025-09-29 16:02:06,233 - my_scientific_profile.papers.papers - INFO - WARNING! Cannot parse doi 10.26434/chemrxiv-2024-m9sk0-v3
